# %%
# !pip install --pre unified-planning==1.0.0.95.dev1
# !pip install up_fast_downward==0.3.1
# Out:
# Requirement already satisfied: unified-planning==1.0.0.95.dev1 in /usr/local/lib/python3.10/dist-packages (1.0.0.95.dev1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from unified-planning==1.0.0.95.dev1) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unified-planning==1.0.0.95.dev1) (3.1)
# Requirement already satisfied: ConfigSpace in /usr/local/lib/python3.10/dist-packages (from unified-planning==1.0.0.95.dev1) (0.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.0.0.95.dev1) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.0.0.95.dev1) (1.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.0.0.95.dev1) (4.5.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from ConfigSpace->unified-planning==1.0.0.95.dev1) (10.1.0)
# Requirement already satisfied: up_fast_downward==0.3.1 in /usr/local/lib/python3.10/dist-packages (0.3.1)

# %%
# !pip install matplotlib==3.7.1  # for visualisation in this notebook
# Out:
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.1) (1.16.0)

# %%
from unified_planning.shortcuts import *

import unified_planning as up

up.shortcuts.get_environment().credits_stream = None

# %% [markdown]
# ## Part (a): Model the Task
#
# The code below models a simpler version of the Household Robot domain with two rooms and one open door between them. The robot is in room A initially and needs to move to room B. You can use it as a starting point for your own solution to the full Household Robot task.

# %%
def get_planning_task():
    # Declare user types.
    Room = UserType("Room")
    Door = UserType("Door")
    Key = UserType("Key")

    # Declare predicates.
    robot_in = up.model.Fluent("robot_in", BoolType(), r=Room)
    connected = up.model.Fluent("connected", BoolType(), r1=Room, d=Door, r2=Room)
    room_has_door = up.model.Fluent("room_has_door", BoolType(), r=Room, d=Door)
    door_is_open = up.model.Fluent("door_is_open", BoolType(), d=Door)
    room_has_key = up.model.Fluent("room_has_key", BoolType(), r=Room, k=Key) #which keys are present in room
    robot_has_key = up.model.Fluent("robot_has_key", BoolType(), k=Key) #which key the robot has picked
    door_key_match = up.model.Fluent("door_key_match", BoolType(), d=Door, k=Key) #which key open which door

    # Add (typed) objects to problem.
    problem = up.model.Problem("household")

    def get_room(room):
        return up.model.Object(f"room{room}", Room)

    def get_door(door):
        return up.model.Object(f"door{door}", Door)

    def get_key(key):
        return up.model.Object(f"key{key}", Key)

    roomLivingRoom = get_room("LivingRoom")
    roomCorridor = get_room("Corridor")
    roomKitchen = get_room("Kitchen")
    roomBathroom = get_room("Bathroom")
    roomLobby = get_room("Lobby")
    rooms = [roomLivingRoom, roomCorridor, roomKitchen, roomBathroom, roomLobby]

    doorLivingRoom = get_door("LivingRoom")
    doorKitchen = get_door("Kitchen")
    doorCorridor = get_door("Corridor")
    doorBathroom = get_door("Bathroom")
    doorLobby = get_door("Lobby")
    doors = [doorLivingRoom, doorKitchen, doorCorridor, doorBathroom, doorLobby]


    keyLivingRoom = get_key("LivingRoom")
    keyKitchen = get_key("Kitchen")
    keyCorridor = get_key("Corridor")
    keyBathroom = get_key("Bathroom")
    keyLobby = get_key("Lobby")
    keys = [keyLivingRoom, keyKitchen, keyCorridor, keyBathroom, keyLobby]


    problem.add_objects(rooms)
    problem.add_objects(doors)
    problem.add_objects(keys)

    connections = [
        (roomLivingRoom, doorKitchen, roomKitchen),
        (roomLivingRoom, doorLivingRoom, roomCorridor),
        (roomCorridor, doorBathroom, roomBathroom),
        (roomCorridor, doorCorridor, roomLobby)
    ]

    rooms_and_doors = []
    for room1, door, room2 in connections:
        rooms_and_doors.append((room1, door))
        rooms_and_doors.append((room2, door))

    rooms_and_doors.append((roomLobby, doorLobby))

    keys_locations = [
        (roomLivingRoom, keyLivingRoom),
        (roomLivingRoom, keyKitchen),
        (roomCorridor, keyBathroom),
        (roomBathroom, keyLobby),
        (roomBathroom, keyCorridor)
    ]

    door_keys = [
        (doorLivingRoom, keyLivingRoom),
        (doorKitchen, keyKitchen),
        (doorCorridor, keyCorridor),
        (doorBathroom, keyBathroom),
        (doorLobby, keyLobby)
    ]


    # Specify the initial state.
    problem.add_fluent(robot_in, default_initial_value=False)
    problem.add_fluent(connected, default_initial_value=False)
    problem.add_fluent(room_has_door, default_initial_value=False)
    problem.add_fluent(door_is_open, default_initial_value=False)
    problem.add_fluent(robot_has_key, default_initial_value=False)
    problem.add_fluent(door_key_match, default_initial_value=False)
    problem.add_fluent(room_has_key, default_initial_value=False)
    problem.set_initial_value(robot_in(roomLivingRoom), True)

    for room1, door, room2 in connections:
        problem.set_initial_value(connected(room1, door, room2), True)
        problem.set_initial_value(connected(room2, door, room1), True)

    for room, door in rooms_and_doors:
        problem.set_initial_value(room_has_door(room, door), True)

    for room, key in keys_locations:
        problem.set_initial_value(room_has_key(room, key), True)

    for door, key in door_keys:
        problem.set_initial_value(door_key_match(door, key), True)

    # Add actions.
    move = up.model.InstantaneousAction("move", room1=Room, door=Door, room2=Room)
    room1 = move.parameter("room1")
    door = move.parameter("door")
    room2 = move.parameter("room2")
    move.add_precondition(robot_in(room1))
    move.add_precondition(connected(room1, door, room2))
    move.add_precondition(door_is_open(door))
    move.add_effect(robot_in(room1), False)
    move.add_effect(robot_in(room2), True)
    problem.add_action(move)

    open = up.model.InstantaneousAction("open", room=Room, door=Door, key=Key)
    room = open.parameter("room")
    door = open.parameter("door")
    key = open.parameter("key")
    open.add_precondition(robot_in(room))
    open.add_precondition(robot_has_key(key))
    open.add_precondition(room_has_door(room, door))
    open.add_precondition(door_key_match(door, key))
    open.add_effect(door_is_open(door), True)
    problem.add_action(open)

    pick = up.model.InstantaneousAction("pick", room=Room, key=Key)
    room = pick.parameter("room")
    key = pick.parameter("key")
    pick.add_precondition(robot_in(room))
    pick.add_precondition(room_has_key(room, key))
    pick.add_effect(room_has_key(room, key), False)
    pick.add_effect(robot_has_key(key), True)
    problem.add_action(pick)

    # Specify the goal.
    problem.add_goal(door_is_open(doorLobby))

    # We want to minimize the plan cost.
    problem.add_quality_metric(MinimizeActionCosts({}, default=Int(1)))
    return problem

problem = get_planning_task()

# %% [markdown]
# ## Part (b): Find a (possibly suboptimal) plan
#
# Solve the task with greedy best-first search using the FF heuristic. The example code below uses the h^add heuristic. You need to inspect the output to stdout to see the heuristic value of the initial state.

# %%
params = {
    "fast_downward_search_config": "eager_greedy([ff()])",
    "log_level": "info"
}

with OneshotPlanner(name="fast-downward", params=params) as planner:
    result = planner.solve(problem, output_stream=sys.stdout)
    if result.status == up.engines.PlanGenerationResultStatus.SOLVED_SATISFICING:
        print("Found a plan of length:", len(result.plan.actions))
        print(result.plan)
        with PlanValidator() as validator:
            val_result = validator.validate(problem, result.plan)
            print("Plan cost:", val_result.metric_evaluations)
    else:
        print("No plan found.", result.log_messages)
# Out:
# INFO     planner time limit: None
# INFO     planner memory limit: None
#
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/bin/python3 /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/translate/translate.py /tmp/tmpwubk7025/domain.pddl /tmp/tmpwubk7025/problem.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.002s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 18 rules.
# Computing model... [0.010s CPU, 0.001s wall-clock]
# 110 relevant atoms
# 69 auxiliary atoms
# 179 final queue length
# 187 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# Instantiating: [0.010s CPU, 0.007s wall-clock]
# Computing fact groups...
# Finding invariants...
# 9 initial candidates
# Finding invariants: [0.000s CPU, 0.001s wall-clock]
# Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
# Instantiating groups... [0.000s CPU, 0.001s wall-clock]
# Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
# Choosing groups...
# 5 uncovered facts
# Choosing groups: [0.000s CPU, 0.000s wall-clock]
# Building translation key... [0.000s CPU, 0.000s wall-clock]
# Computing fact groups: [0.000s CPU, 0.003s wall-clock]
# Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
# Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
# Building mutex information...
# Building mutex information: [0.000s CPU, 0.000s wall-clock]
# Translating task...
# Processing axioms...
# Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
# Translator axioms removed by simplifying: 0
# Computing negative axioms... [0.000s CPU, 0.000s wall-clock]
# Processing axioms: [0.000s CPU, 0.000s wall-clock]
# Translating task: [0.000s CPU, 0.001s wall-clock]
# 0 effect conditions simplified
# 0 implied preconditions added
# Detecting unreachable propositions...
# 0 operators removed
# 0 axioms removed
# 6 propositions removed
# Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
# Reordering and filtering variables...
# 11 of 11 variables necessary.
# 0 of 6 mutex groups necessary.
# 22 of 22 operators necessary.
# 0 of 0 axiom rules necessary.
# Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
# Translator variables: 11
# Translator derived variables: 0
# Translator facts: 25
# Translator goal facts: 1
# Translator mutex groups: 0
# Translator total mutex groups size: 0
# Translator operators: 22
# Translator axioms: 0
# Translator task size: 125
# Translator peak memory: 31476 KB
# Writing output... [0.000s CPU, 0.001s wall-clock]
# Done! [0.010s CPU, 0.017s wall-clock]
# translate exit code: 0
#
# INFO     Running search (release).
# INFO     search stdin: output.sas
# INFO     search time limit: None
# INFO     search memory limit: None
# INFO     search command line string: /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/downward --search 'eager_greedy([ff()])' --internal-plan-file /tmp/tmpwubk7025/plan.txt < output.sas
# [t=0.00215368s, 10804 KB] reading input...
# [t=0.00267971s, 10804 KB] done reading input!
# [t=0.00480304s, 11060 KB] Simplifying 22 unary operators... done! [22 unary operators]
# [t=0.00494211s, 11060 KB] time to simplify: 0.000198583s
# [t=0.00501431s, 11060 KB] Initializing additive heuristic...
# [t=0.00504333s, 11060 KB] Initializing FF heuristic...
# [t=0.00509512s, 11060 KB] Building successor generator...done!
# [t=0.00520294s, 11060 KB] peak memory difference for successor generator creation: 0 KB
# [t=0.005228s, 11060 KB] time for successor generation creation: 3.9103e-05s
# [t=0.00526258s, 11060 KB] Variables: 11
# [t=0.00530406s, 11060 KB] FactPairs: 25
# [t=0.0053268s, 11060 KB] Bytes per state: 4
# [t=0.00539208s, 11060 KB] Conducting best first search without reopening closed nodes, (real) bound = 2147483647
# [t=0.00546065s, 11060 KB] New best heuristic value for ff(): 11
# [t=0.00549406s, 11060 KB] g=0, 1 evaluated, 0 expanded
# [t=0.00552704s, 11060 KB] Initial heuristic value for ff(): 11
# [t=0.00555793s, 11060 KB] pruning method: none
# [t=0.00560054s, 11060 KB] New best heuristic value for ff(): 10
# [t=0.00562808s, 11060 KB] g=1, 3 evaluated, 1 expanded
# [t=0.00566455s, 11060 KB] New best heuristic value for ff(): 9
# [t=0.00569008s, 11060 KB] g=2, 5 evaluated, 2 expanded
# [t=0.00572275s, 11060 KB] New best heuristic value for ff(): 8
# [t=0.00575175s, 11060 KB] g=3, 7 evaluated, 3 expanded
# [t=0.00578756s, 11060 KB] New best heuristic value for ff(): 7
# [t=0.00581319s, 11060 KB] g=4, 8 evaluated, 4 expanded
# [t=0.0058668s, 11060 KB] New best heuristic value for ff(): 6
# [t=0.00589322s, 11060 KB] g=5, 9 evaluated, 5 expanded
# [t=0.00594304s, 11060 KB] New best heuristic value for ff(): 5
# [t=0.00596919s, 11060 KB] g=7, 13 evaluated, 7 expanded
# [t=0.00600562s, 11060 KB] New best heuristic value for ff(): 4
# [t=0.00603366s, 11060 KB] g=8, 16 evaluated, 8 expanded
# [t=0.00606829s, 11060 KB] New best heuristic value for ff(): 3
# [t=0.00609436s, 11060 KB] g=9, 17 evaluated, 9 expanded
# [t=0.00612449s, 11060 KB] New best heuristic value for ff(): 2
# [t=0.00614962s, 11060 KB] g=10, 18 evaluated, 10 expanded
# [t=0.00618802s, 11060 KB] New best heuristic value for ff(): 1
# [t=0.00621654s, 11060 KB] g=11, 21 evaluated, 11 expanded
# [t=0.00625011s, 11060 KB] New best heuristic value for ff(): 0
# [t=0.00627644s, 11060 KB] g=12, 23 evaluated, 12 expanded
# [t=0.00631123s, 11060 KB] Solution found!
# [t=0.00633821s, 11060 KB] Actual search time: 0.000777955s
# pick roomlivingroom keylivingroom (1)
# open roomlivingroom doorlivingroom keylivingroom (1)
# move roomlivingroom doorlivingroom roomcorridor (1)
# pick roomcorridor keybathroom (1)
# open roomcorridor doorbathroom keybathroom (1)
# move roomcorridor doorbathroom roombathroom (1)
# pick roombathroom keycorridor (1)
# pick roombathroom keylobby (1)
# move roombathroom doorbathroom roomcorridor (1)
# open roomcorridor doorcorridor keycorridor (1)
# move roomcorridor doorcorridor roomlobby (1)
# open roomlobby doorlobby keylobby (1)
# [t=0.00635896s, 11060 KB] Plan length: 12 step(s).
# [t=0.00635896s, 11060 KB] Plan cost: 12
# [t=0.00635896s, 11060 KB] Expanded 13 state(s).
# [t=0.00635896s, 11060 KB] Reopened 0 state(s).
# [t=0.00635896s, 11060 KB] Evaluated 23 state(s).
# [t=0.00635896s, 11060 KB] Evaluations: 23
# [t=0.00635896s, 11060 KB] Generated 40 state(s).
# [t=0.00635896s, 11060 KB] Dead ends: 0 state(s).
# [t=0.00635896s, 11060 KB] Number of registered states: 23
# [t=0.00635896s, 11060 KB] Int hash set load factor: 23/32 = 0.71875
# [t=0.00635896s, 11060 KB] Int hash set resizes: 5
# [t=0.00635896s, 11060 KB] Search time: 0.000968379s
# [t=0.00635896s, 11060 KB] Total time: 0.00635896s
# Solution found.
# Peak memory: 11060 KB
# Remove intermediate file output.sas
# search exit code: 0
#
# INFO     Planner time: 0.16s
# Found a plan of length: 12
# SequentialPlan:
#     pick(roomLivingRoom, keyLivingRoom)
#     open(roomLivingRoom, doorLivingRoom, keyLivingRoom)
#     move(roomLivingRoom, doorLivingRoom, roomCorridor)
#     pick(roomCorridor, keyBathroom)
#     open(roomCorridor, doorBathroom, keyBathroom)
#     move(roomCorridor, doorBathroom, roomBathroom)
#     pick(roomBathroom, keyCorridor)
#     pick(roomBathroom, keyLobby)
#     move(roomBathroom, doorBathroom, roomCorridor)
#     open(roomCorridor, doorCorridor, keyCorridor)
#     move(roomCorridor, doorCorridor, roomLobby)
#     open(roomLobby, doorLobby, keyLobby)
# Plan cost: {minimize actions-cost: {'default': 1}: 12}

# %% [markdown]
# # Planning Lab

# %% [markdown]
# ## Part (c): Find an optimal plan
#
# Solve the task with A* using the `iPDB` heuristic.

# %%
params = {
    "fast_downward_search_config": "astar(ipdb())",
    "log_level": "info"
}

with OneshotPlanner(name="fast-downward", params=params) as planner:
    result = planner.solve(problem, output_stream=sys.stdout)
    if result.status == up.engines.PlanGenerationResultStatus.SOLVED_SATISFICING:
        print("Found a plan of length:", len(result.plan.actions))
        print(result.plan)
        with PlanValidator() as validator:
            val_result = validator.validate(problem, result.plan)
            print("Plan cost:", val_result.metric_evaluations)
    else:
        print("No plan found.")
# Out:
# INFO     planner time limit: None
# INFO     planner memory limit: None
#
# INFO     Running translator.
# INFO     translator stdin: None
# INFO     translator time limit: None
# INFO     translator memory limit: None
# INFO     translator command line string: /usr/bin/python3 /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/translate/translate.py /tmp/tmpw1swuhj1/domain.pddl /tmp/tmpw1swuhj1/problem.pddl --sas-file output.sas
# Parsing...
# Parsing: [0.000s CPU, 0.003s wall-clock]
# Normalizing task... [0.000s CPU, 0.000s wall-clock]
# Instantiating...
# Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
# Normalizing Datalog program...
# Normalizing Datalog program: [0.000s CPU, 0.001s wall-clock]
# Preparing model... [0.000s CPU, 0.001s wall-clock]
# Generated 18 rules.
# Computing model... [0.010s CPU, 0.001s wall-clock]
# 110 relevant atoms
# 69 auxiliary atoms
# 179 final queue length
# 187 total queue pushes
# Completing instantiation... [0.000s CPU, 0.001s wall-clock]
# Instantiating: [0.010s CPU, 0.005s wall-clock]
# Computing fact groups...
# Finding invariants...
# 9 initial candidates
# Finding invariants: [0.000s CPU, 0.001s wall-clock]
# Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
# Instantiating groups... [0.000s CPU, 0.000s wall-clock]
# Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
# Choosing groups...
# 5 uncovered facts
# Choosing groups: [0.000s CPU, 0.000s wall-clock]
# Building translation key... [0.000s CPU, 0.000s wall-clock]
# Computing fact groups: [0.000s CPU, 0.003s wall-clock]
# Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
# Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
# Building mutex information...
# Building mutex information: [0.000s CPU, 0.000s wall-clock]
# Translating task...
# Processing axioms...
# Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
# Translator axioms removed by simplifying: 0
# Computing negative axioms... [0.000s CPU, 0.000s wall-clock]
# Processing axioms: [0.000s CPU, 0.000s wall-clock]
# Translating task: [0.000s CPU, 0.001s wall-clock]
# 0 effect conditions simplified
# 0 implied preconditions added
# Detecting unreachable propositions...
# 0 operators removed
# 0 axioms removed
# 6 propositions removed
# Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
# Reordering and filtering variables...
# 11 of 11 variables necessary.
# 0 of 6 mutex groups necessary.
# 22 of 22 operators necessary.
# 0 of 0 axiom rules necessary.
# Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
# Translator variables: 11
# Translator derived variables: 0
# Translator facts: 25
# Translator goal facts: 1
# Translator mutex groups: 0
# Translator total mutex groups size: 0
# Translator operators: 22
# Translator axioms: 0
# Translator task size: 125
# Translator peak memory: 31476 KB
# Writing output... [0.000s CPU, 0.001s wall-clock]
# Done! [0.010s CPU, 0.014s wall-clock]
# translate exit code: 0
#
# INFO     Running search (release).
# INFO     search stdin: output.sas
# INFO     search time limit: None
# INFO     search memory limit: None
# INFO     search command line string: /usr/local/lib/python3.10/dist-packages/up_fast_downward/downward/builds/release/bin/downward --search 'astar(ipdb())' --internal-plan-file /tmp/tmpw1swuhj1/plan.txt < output.sas
# [t=0.00215186s, 10804 KB] reading input...
# [t=0.00264285s, 10804 KB] done reading input!
# [t=0.00484303s, 11060 KB] Initializing canonical PDB heuristic...
# [t=0.00491488s, 11060 KB] Generating patterns using: hill climbing pattern collection generator
# [t=0.0049848s, 11060 KB] Done calculating initial pattern collection: 6.4094e-05s
# [t=0.00502328s, 11060 KB] Average operator cost: 1
# [t=0.00505268s, 11060 KB] building causal graph...done! [t=5.3183e-05s]
# [t=0.0051614s, 11060 KB] Done calculating initial candidate PDBs
# [t=0.00649312s, 11060 KB] found a better pattern with improvement 1000
# [t=0.00882s, 11060 KB] found a better pattern with improvement 1000
# [t=0.0118676s, 11060 KB] found a better pattern with improvement 997
# [t=0.0167371s, 11060 KB] found a better pattern with improvement 954
# [t=0.0237745s, 11060 KB] found a better pattern with improvement 701
# [t=0.0307479s, 11060 KB] found a better pattern with improvement 428
# [t=0.038837s, 11060 KB] found a better pattern with improvement 57
# [t=0.0485191s, 11060 KB] Improvement below threshold. Stop hill climbing.
# [t=0.0486588s, 11060 KB] Hill climbing iterations: 8
# [t=0.0486925s, 11060 KB] Hill climbing generated patterns: 26
# [t=0.0487284s, 11060 KB] Hill climbing rejected patterns: 0
# [t=0.0487483s, 11060 KB] Hill climbing maximum PDB size: 1280
# [t=0.0487666s, 11060 KB] Hill climbing time: 0.0437632s
# [t=0.0489163s, 11060 KB] hill climbing pattern collection generator number of patterns: 8
# [t=0.048966s, 11060 KB] hill climbing pattern collection generator total PDB size: 1272
# [t=0.0489919s, 11060 KB] hill climbing pattern collection generator computation time: 0.0439653s
# [t=0.0490192s, 11060 KB] Running dominance pruning...
# [t=0.0490439s, 11060 KB] Pruned 7 of 8 pattern cliques
# [t=0.0490646s, 11060 KB] Pruned 7 of 8 PDBs
# [t=0.0490862s, 11060 KB] Dominance pruning took 6.5358e-05s
# [t=0.0491136s, 11060 KB] Canonical PDB heuristic number of patterns: 1
# [t=0.0491382s, 11060 KB] Canonical PDB heuristic total PDB size: 640
# [t=0.0491602s, 11060 KB] Canonical PDB heuristic computation time: 0.0442726s
# [t=0.0492323s, 11060 KB] Building successor generator...done!
# [t=0.0493485s, 11060 KB] peak memory difference for successor generator creation: 0 KB
# [t=0.0493732s, 11060 KB] time for successor generation creation: 3.1692e-05s
# [t=0.0494004s, 11060 KB] Variables: 11
# [t=0.0494462s, 11060 KB] FactPairs: 25
# [t=0.049472s, 11060 KB] Bytes per state: 4
# [t=0.0495451s, 11060 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
# [t=0.0496039s, 11060 KB] New best heuristic value for : 11
# [t=0.049632s, 11060 KB] g=0, 1 evaluated, 0 expanded
# [t=0.0496579s, 11060 KB] f = 11, 1 evaluated, 0 expanded
# [t=0.0496884s, 11060 KB] Initial heuristic value for : 11
# [t=0.0497151s, 11060 KB] pruning method: none
# [t=0.0497655s, 11060 KB] f = 12, 3 evaluated, 1 expanded
# [t=0.0498037s, 11060 KB] New best heuristic value for : 10
# [t=0.0498293s, 11060 KB] g=2, 6 evaluated, 3 expanded
# [t=0.0498617s, 11060 KB] New best heuristic value for : 9
# [t=0.0498872s, 11060 KB] g=3, 8 evaluated, 4 expanded
# [t=0.0499191s, 11060 KB] New best heuristic value for : 8
# [t=0.0499448s, 11060 KB] g=4, 9 evaluated, 5 expanded
# [t=0.0499759s, 11060 KB] New best heuristic value for : 7
# [t=0.050012s, 11060 KB] g=5, 10 evaluated, 6 expanded
# [t=0.0500468s, 11060 KB] New best heuristic value for : 6
# [t=0.0500703s, 11060 KB] g=6, 12 evaluated, 7 expanded
# [t=0.0500991s, 11060 KB] New best heuristic value for : 5
# [t=0.0501239s, 11060 KB] g=7, 14 evaluated, 8 expanded
# [t=0.0501909s, 11060 KB] New best heuristic value for : 4
# [t=0.0502177s, 11060 KB] g=8, 17 evaluated, 9 expanded
# [t=0.0502494s, 11060 KB] New best heuristic value for : 3
# [t=0.0502749s, 11060 KB] g=9, 18 evaluated, 10 expanded
# [t=0.0503045s, 11060 KB] New best heuristic value for : 2
# [t=0.0503296s, 11060 KB] g=10, 19 evaluated, 11 expanded
# [t=0.050367s, 11060 KB] New best heuristic value for : 1
# [t=0.0503922s, 11060 KB] g=11, 22 evaluated, 12 expanded
# [t=0.0504382s, 11060 KB] New best heuristic value for : 0
# [t=0.0504687s, 11060 KB] g=12, 24 evaluated, 13 expanded
# [t=0.0504967s, 11060 KB] Solution found!
# [t=0.0505302s, 11060 KB] Actual search time: 0.000822293s
# pick roomlivingroom keylivingroom (1)
# open roomlivingroom doorlivingroom keylivingroom (1)
# move roomlivingroom doorlivingroom roomcorridor (1)
# pick roomcorridor keybathroom (1)
# open roomcorridor doorbathroom keybathroom (1)
# move roomcorridor doorbathroom roombathroom (1)
# pick roombathroom keycorridor (1)
# pick roombathroom keylobby (1)
# move roombathroom doorbathroom roomcorridor (1)
# open roomcorridor doorcorridor keycorridor (1)
# move roomcorridor doorcorridor roomlobby (1)
# open roomlobby doorlobby keylobby (1)
# [t=0.0505663s, 11060 KB] Plan length: 12 step(s).
# [t=0.0505663s, 11060 KB] Plan cost: 12
# [t=0.0505663s, 11060 KB] Expanded 14 state(s).
# [t=0.0505663s, 11060 KB] Reopened 0 state(s).
# [t=0.0505663s, 11060 KB] Evaluated 24 state(s).
# [t=0.0505663s, 11060 KB] Evaluations: 24
# [t=0.0505663s, 11060 KB] Generated 42 state(s).
# [t=0.0505663s, 11060 KB] Dead ends: 0 state(s).
# [t=0.0505663s, 11060 KB] Expanded until last jump: 1 state(s).
# [t=0.0505663s, 11060 KB] Reopened until last jump: 0 state(s).
# [t=0.0505663s, 11060 KB] Evaluated until last jump: 3 state(s).
# [t=0.0505663s, 11060 KB] Generated until last jump: 2 state(s).
# [t=0.0505663s, 11060 KB] Number of registered states: 24
# [t=0.0505663s, 11060 KB] Int hash set load factor: 24/32 = 0.75
# [t=0.0505663s, 11060 KB] Int hash set resizes: 5
# [t=0.0505663s, 11060 KB] Search time: 0.00103086s
# [t=0.0505663s, 11060 KB] Total time: 0.0505663s
# Solution found.
# Peak memory: 11060 KB
# Remove intermediate file output.sas
# search exit code: 0
#
# INFO     Planner time: 0.21s
# Found a plan of length: 12
# SequentialPlan:
#     pick(roomLivingRoom, keyLivingRoom)
#     open(roomLivingRoom, doorLivingRoom, keyLivingRoom)
#     move(roomLivingRoom, doorLivingRoom, roomCorridor)
#     pick(roomCorridor, keyBathroom)
#     open(roomCorridor, doorBathroom, keyBathroom)
#     move(roomCorridor, doorBathroom, roomBathroom)
#     pick(roomBathroom, keyCorridor)
#     pick(roomBathroom, keyLobby)
#     move(roomBathroom, doorBathroom, roomCorridor)
#     open(roomCorridor, doorCorridor, keyCorridor)
#     move(roomCorridor, doorCorridor, roomLobby)
#     open(roomLobby, doorLobby, keyLobby)
# Plan cost: {minimize actions-cost: {'default': 1}: 12}
